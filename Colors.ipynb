# %% [markdown]
# ## Swatches for Color Sequences in Plotly and Matplotlib

# %% [markdown]
# -  A swatch of colors refers to a small sample or display of various colors, which can be arranged in a systematic way.
#
# - Swatches are commonly used in design, art, fashion, and other creative fields to showcase and choose specific colors for a project. They can be physical samples, such as paint chips or fabric samples, or digital representations (like the ones we are going to make here).
#
# - Swatches are helpful for visualizing and comparing different colors, ensuring consistency and coherence in a design or artistic work. They are particularly useful when selecting colors for various elements like backgrounds, text, or accents in a project.
#
# - In this notebook, I am going to make swatches of colors using the Python libraries plotly and matplotlib.

# %%
# %config InlineBackend.figure_format ='retina'

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ### Swatches in Plotly
#
# - Plotly express library provides **color sequences** which are lists of colors to be mapped onto discrete data values. No interpolation occurs when using color sequences, unlike with continuous color scales, and each color is used as-is.
#
#
# - Besides, plotly express provides functionality, via the method `scolors.qualitative.swatches`,  to print swatches for all the color sequences available.

# %%
# Source: https://plotly.com/python/discrete-color/
import plotly.express as px
fig = px.colors.qualitative.swatches()
fig.show()

# %% [markdown]
# The swatches are interactive, as expected from plotly,  so you can see the individual color specifications by hoovering above the swatches.

# %% [markdown]
# Some of the color qualitative sequences, such as Plotly and G10, contain colors in Hexadecimal format. The Hex color codes start with a pound sign or hashtag (#) and are followed by six letters and/or numbers. The first two letters/numbers refer to red, the next two refer to green, and the last two refer to blue.

# %%
palette_plotly = px.colors.qualitative.Plotly
palette_plotly
# Out:
# ['#636EFA',
#  '#EF553B',
#  '#00CC96',
#  '#AB63FA',
#  '#FFA15A',
#  '#19D3F3',
#  '#FF6692',
#  '#B6E880',
#  '#FF97FF',
#  '#FECB52']

# %% [markdown]
# Other color qualitative sequences, such as Bold and  Pastel, contain colors in RGB format.
# The format of an RGB value in the functional notation is 'rgb(' followed by a comma-separated list of three numerical values (three integer values(0-255, 0-255, 0-255)) followed by ')'.

# %%
palette_pastel = px.colors.qualitative.Pastel
palette_pastel
# Out:
# ['rgb(102, 197, 204)',
#  'rgb(246, 207, 113)',
#  'rgb(248, 156, 116)',
#  'rgb(220, 176, 242)',
#  'rgb(135, 197, 95)',
#  'rgb(158, 185, 243)',
#  'rgb(254, 136, 177)',
#  'rgb(201, 219, 116)',
#  'rgb(139, 224, 164)',
#  'rgb(180, 151, 231)',
#  'rgb(179, 179, 179)']

# %% [markdown]
# ### Swatches in Matplotlib
#
# Matplolib also offers a number of built-in sequential colormaps accessible via `matplotlib.colormaps`.

# %% [markdown]
# To print the swatches for the sequential colormaps, we need to load the libraries  `colorspacious`, and `numpy` and to us a small function whose implementation is available in the `matplotlib` documentation webseite (You can find it [Here!](https://matplotlib.org/stable/users/explain/colors/colormaps.html))

# %%
# Source: https://matplotlib.org/stable/users/explain/colors/colormaps.html

from colorspacious import cspace_converter

import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl


cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=mpl.colormaps[name])
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list

# %%
plot_color_gradients('Qualitative',
                     ['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2',
                      'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b',
                      'tab20c'])

# %% [markdown]
# We can also print individual swatches for each fo the color maps.

# %%
plt.cm.tab20

# %% [markdown]
# However, we can print the indidual color specifications as follows.

# %%
plt.cm.tab20.colors
# Out:
# ((0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (0.6823529411764706, 0.7803921568627451, 0.9098039215686274),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (1.0, 0.7333333333333333, 0.47058823529411764),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.596078431372549, 0.8745098039215686, 0.5411764705882353),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (1.0, 0.596078431372549, 0.5882352941176471),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.7725490196078432, 0.6901960784313725, 0.8352941176470589),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.7686274509803922, 0.611764705882353, 0.5803921568627451),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.9686274509803922, 0.7137254901960784, 0.8235294117647058),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7803921568627451, 0.7803921568627451, 0.7803921568627451),
# ...

# %% [markdown]
# The disadvantage of this format is that we cannot see the specifications next to the corresponding colors.
#
#
# However, `matplotlib` provides the following helper function which allows us to print color tables for common color categories.

# %%
# Source: https://matplotlib.org/stable/gallery/color/named_colors.html

import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=1, sort_colors=False):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %% [markdown]
# Note that this helper function prints  the name of the color next to the swatch.

# %%
plot_colortable(mcolors.TABLEAU_COLORS)
plt.show()

# %% [markdown]
# This is because the input is a dictionary of the following form.

# %%
mcolors.TABLEAU_COLORS
# Out:
# {'tab:blue': '#1f77b4',
#  'tab:orange': '#ff7f0e',
#  'tab:green': '#2ca02c',
#  'tab:red': '#d62728',
#  'tab:purple': '#9467bd',
#  'tab:brown': '#8c564b',
#  'tab:pink': '#e377c2',
#  'tab:gray': '#7f7f7f',
#  'tab:olive': '#bcbd22',
#  'tab:cyan': '#17becf'}

# %% [markdown]
# So, we can easily modify the input to produce our color swatches.

# %%
tableau_colors = { v:v for v in mcolors.TABLEAU_COLORS.values()}
plot_colortable(tableau_colors)
plt.show()

# %% [markdown]
# Similarly, we can make swatches for the sequential colormaps as follows.

# %%
tab20_dict = {k: k for v, k in enumerate(plt.cm.tab20.colors)}
plot_colortable(tab20_dict)
plt.show()

# %% [markdown]
# We can use a similar approach to make swatches for the plotly color sequences.

# %%
colors_dict = {k: k for v, k in enumerate(palette_plotly)}
plot_colortable(colors_dict)
plt.show()

# %%
colors_dict = {k: k for v, k in enumerate( px.colors.qualitative.D3 +
                                          px.colors.qualitative.G10 + px.colors.qualitative.Alphabet)}
plot_colortable(colors_dict, ncols=4)
plt.show()

# %% [markdown]
# Note that for those which are in the rgb format need to be trasformed before creating the swatches.

# %%
palette = px.colors.qualitative.Bold
colors = [(a/255, b/255, c/255) for (a,b,c) in [eval(p[4:-1]) for p in palette]]
colors_dict = {str(p): c  for p, c in zip(palette,colors)}
plot_colortable(colors_dict)
plt.show()

# %% [markdown]
# In the next example I am adding a fourth argument into each color-tuple to account for transparency. This is useful when you want to use a specific color palette but in a more transparent configuration.

# %%
palette = px.colors.qualitative.Bold
colors_transparent = [(a/255, b/255, c/255, 0.25) for (a,b,c) in [eval(p[4:-1]) for p in palette]]
colors_dict = {'rgba'+str(k): k for v, k in enumerate(colors_transparent)}
plot_colortable(colors_dict)
plt.show()

# %% [markdown]
# Finally, I want to show a subset (since they are way too many to print here) of the XKCD_COLORS. For this, I create a helper function which takes the first n elements.

# %%
from itertools import islice
def take(n, iterable):
    """Return the first n items of the iterable as a list."""
    return dict(list(islice(iterable, n)))

# %%
subset_colors = take(10, mcolors.XKCD_COLORS.items())
plot_colortable(subset_colors)
plt.show()
